# %%
import pandas as pd

# %%
df = pd.read_csv('yt_df.csv')

# %%
df.head()
# Out:
#   Rank       Username           Categories   Suscribers         Country  \
# 0    1        tseries       Música y baile  253500000.0           India
# 1    2        MrBeast   Videojuegos, Humor  210100000.0  Estados Unidos
# 2    3      CoComelon            Educación  168100000.0         Unknown
# 3    4       SETIndia                  NaN  165400000.0           India
# 4    5  KidsDianaShow  Animación, Juguetes  116500000.0         Unknown
#
#        Visits      Likes  Comments  \
# 0    111300.0     3200.0     120.0
# 1  95400000.0  5400000.0   16600.0
# 2   4100000.0    21600.0       0.0
# 3     23300.0      239.0       9.0
# 4   4100000.0     8800.0       0.0
#
#                                                Links
# 0  http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2  http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   object
#  1   Username    1000 non-null   object
#  2   Categories  676 non-null    object
#  3   Suscribers  1000 non-null   float64
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   float64
#  6   Likes       1000 non-null   float64
#  7   Comments    1000 non-null   float64
#  8   Links       1000 non-null   object
# dtypes: float64(4), object(5)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#          Suscribers        Visits         Likes       Comments
# count  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000
# mean   2.260980e+07  1.063825e+06  4.917148e+04    1866.295000
# std    1.733998e+07  3.729356e+06  2.107156e+05   20503.291953
# min    1.230000e+07  0.000000e+00  0.000000e+00       0.000000
# 25%    1.430000e+07  3.310000e+04  4.792500e+02       3.000000
# 50%    1.730000e+07  1.932000e+05  3.400000e+03      70.000000
# 75%    2.442500e+07  8.844500e+05  3.080000e+04     458.250000
# max    2.535000e+08  9.540000e+07  5.400000e+06  532000.000000

# %%
df.isna().sum()
# Out:
# Rank            0
# Username        0
# Categories    324
# Suscribers      0
# Country         0
# Visits          0
# Likes           0
# Comments        0
# Links           0
# dtype: int64

# %%
df['Categories'].fillna('Unknow', inplace=True)

# %%
df.isna().sum()
# Out:
# Rank          0
# Username      0
# Categories    0
# Suscribers    0
# Country       0
# Visits        0
# Likes         0
# Comments      0
# Links         0
# dtype: int64

# %%
df.head(20)
# Out:
#        Rank              Username              Categories   Suscribers  \
# 0         1               tseries          Música y baile  253500000.0
# 1         2               MrBeast      Videojuegos, Humor  210100000.0
# 2         3             CoComelon               Educación  168100000.0
# 3         4              SETIndia                  Unknow  165400000.0
# 4         5         KidsDianaShow     Animación, Juguetes  116500000.0
# 5      658             PewDiePie  Películas, Videojuegos  111400000.0
# 6         7    LikeNastyaofficial                Juguetes  110400000.0
# 7         8           VladandNiki     Animación, Juguetes  105500000.0
# 8         9       zeemusiccompany          Música y baile  102600000.0
# 9        10                   WWE             Videojuegos   98100000.0
# 10    1173             BLACKPINK          Música y baile   92200000.0
# 11       12    GoldminesTelefilms                  Unknow   92100000.0
# ...

# %%
df['Rank'] = df['Rank'].str.replace(r'\D', '', regex=True).astype(int)

# %%
df.head(20)
# Out:
#       Rank              Username              Categories   Suscribers  \
# 0        1               tseries          Música y baile  253500000.0
# 1        2               MrBeast      Videojuegos, Humor  210100000.0
# 2        3             CoComelon               Educación  168100000.0
# 3        4              SETIndia                  Unknow  165400000.0
# 4        5         KidsDianaShow     Animación, Juguetes  116500000.0
# 5      658             PewDiePie  Películas, Videojuegos  111400000.0
# 6        7    LikeNastyaofficial                Juguetes  110400000.0
# 7        8           VladandNiki     Animación, Juguetes  105500000.0
# 8        9       zeemusiccompany          Música y baile  102600000.0
# 9       10                   WWE             Videojuegos   98100000.0
# 10    1173             BLACKPINK          Música y baile   92200000.0
# 11      12    GoldminesTelefilms                  Unknow   92100000.0
# ...

# %%
df.loc[df['Rank'] == 1173, 'Rank'] = 11

# %%
df.loc[df['Rank'] == 1173, 'Rank'] = 11

# %%
df.head(20)
# Out:
#     Rank              Username              Categories   Suscribers  \
# 0      1               tseries          Música y baile  253500000.0
# 1      2               MrBeast      Videojuegos, Humor  210100000.0
# 2      3             CoComelon               Educación  168100000.0
# 3      4              SETIndia                  Unknow  165400000.0
# 4      5         KidsDianaShow     Animación, Juguetes  116500000.0
# 5      6             PewDiePie  Películas, Videojuegos  111400000.0
# 6      7    LikeNastyaofficial                Juguetes  110400000.0
# 7      8           VladandNiki     Animación, Juguetes  105500000.0
# 8      9       zeemusiccompany          Música y baile  102600000.0
# 9     10                   WWE             Videojuegos   98100000.0
# 10    11             BLACKPINK          Música y baile   92200000.0
# 11    12    GoldminesTelefilms                  Unknow   92100000.0
# 12    13               SonySAB    Películas, Animación   87200000.0
# ...

# %%
df.Categories.unique()
# Out:
# array(['Música y baile', 'Videojuegos, Humor', 'Educación', 'Unknow',
#        'Animación, Juguetes', 'Películas, Videojuegos', 'Juguetes',
#        'Videojuegos', 'Películas, Animación', 'Películas',
#        'Noticias y Política', 'Animación, Humor', 'Películas, Humor',
#        'Películas, Juguetes', 'Música y baile, Películas',
#        'Música y baile, Animación', 'Vlogs diarios',
#        'Videojuegos, Juguetes', 'Animación, Videojuegos',
#        'Música y baile, Humor', 'Animación', 'Ciencia y tecnología',
#        'Fitness, Salud y autoayuda', 'Belleza, Moda', 'Humor',
#        'Diseño/arte', 'Comida y bebida', 'Viajes, Espectáculos',
#        'Deportes', 'Fitness', 'Comida y bebida, Salud y autoayuda',
#        'Salud y autoayuda', 'DIY y Life Hacks, Juguetes',
#        'AnimaciónHumorEducación', 'Educación, Juguetes',
#        'Música y baile, Juguetes', 'Juguetes, Coches y vehículos',
#        'Animales y mascotas', 'Belleza', 'ASMR', 'Moda',
# ...

# %%
df1 = pd.read_csv('cleaned_data.csv')

# %%
df1.head(20)
# Out:
#        Rank              Username                 Categories  Suscribers  \
# 0         1               tseries          ['Music & Dance']   253500000
# 1         2               MrBeast   ['Video Games', 'Humor']   210100000
# 2         3             CoComelon              ['Education']   168100000
# 3         4              SETIndia                ['Unknown']   165400000
# 4         5         KidsDianaShow      ['Animation', 'Toys']   116500000
# 5      658             PewDiePie  ['Movies', 'Video Games']   111400000
# 6         7    LikeNastyaofficial                   ['Toys']   110400000
# 7         8           VladandNiki      ['Animation', 'Toys']   105500000
# 8         9       zeemusiccompany          ['Music & Dance']   102600000
# 9        10                   WWE            ['Video Games']    98100000
# 10    1173             BLACKPINK          ['Music & Dance']    92200000
# 11       12    GoldminesTelefilms                ['Unknown']    92100000
# ...

# %%
df1['Rank'] = df1['Rank'].str.replace(r'\D', '', regex=True).astype(int)

# %%
df1.head(20)
# Out:
#       Rank              Username                 Categories  Suscribers  \
# 0        1               tseries          ['Music & Dance']   253500000
# 1        2               MrBeast   ['Video Games', 'Humor']   210100000
# 2        3             CoComelon              ['Education']   168100000
# 3        4              SETIndia                ['Unknown']   165400000
# 4        5         KidsDianaShow      ['Animation', 'Toys']   116500000
# 5      658             PewDiePie  ['Movies', 'Video Games']   111400000
# 6        7    LikeNastyaofficial                   ['Toys']   110400000
# 7        8           VladandNiki      ['Animation', 'Toys']   105500000
# 8        9       zeemusiccompany          ['Music & Dance']   102600000
# 9       10                   WWE            ['Video Games']    98100000
# 10    1173             BLACKPINK          ['Music & Dance']    92200000
# 11      12    GoldminesTelefilms                ['Unknown']    92100000
# ...

# %%
df1.loc[df['Rank'] == 171061, 'Rank'] = 17

# %%
df1.head(20)
# Out:
#       Rank              Username                 Categories  Suscribers  \
# 0        1               tseries          ['Music & Dance']   253500000
# 1        2               MrBeast   ['Video Games', 'Humor']   210100000
# 2        3             CoComelon              ['Education']   168100000
# 3        4              SETIndia                ['Unknown']   165400000
# 4        5         KidsDianaShow      ['Animation', 'Toys']   116500000
# 5      658             PewDiePie  ['Movies', 'Video Games']   111400000
# 6        7    LikeNastyaofficial                   ['Toys']   110400000
# 7        8           VladandNiki      ['Animation', 'Toys']   105500000
# 8        9       zeemusiccompany          ['Music & Dance']   102600000
# 9       10                   WWE            ['Video Games']    98100000
# 10    1173             BLACKPINK          ['Music & Dance']    92200000
# 11      12    GoldminesTelefilms                ['Unknown']    92100000
# ...

# %%
df1.loc[df1['Rank'] == 171061, 'Rank'] = 17

# %%
df1.head(20)
# Out:
#     Rank              Username                 Categories  Suscribers  \
# 0      1               tseries          ['Music & Dance']   253500000
# 1      2               MrBeast   ['Video Games', 'Humor']   210100000
# 2      3             CoComelon              ['Education']   168100000
# 3      4              SETIndia                ['Unknown']   165400000
# 4      5         KidsDianaShow      ['Animation', 'Toys']   116500000
# 5      6             PewDiePie  ['Movies', 'Video Games']   111400000
# 6      7    LikeNastyaofficial                   ['Toys']   110400000
# 7      8           VladandNiki      ['Animation', 'Toys']   105500000
# 8      9       zeemusiccompany          ['Music & Dance']   102600000
# 9     10                   WWE            ['Video Games']    98100000
# 10    11             BLACKPINK          ['Music & Dance']    92200000
# 11    12    GoldminesTelefilms                ['Unknown']    92100000
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
df1.Categories.unique()
# Out:
# array(["['Music & Dance']", "['Video Games', 'Humor']", "['Education']",
#        "['Unknown']", "['Animation', 'Toys']",
#        "['Movies', 'Video Games']", "['Toys']", "['Video Games']",
#        "['Movies', 'Animation']", "['Movies']", "['News & Politics']",
#        "['Animation', 'Humor']", "['Movies', 'Humor']",
#        "['Movies', 'Toys']", "['Music & Dance', 'Movies']",
#        "['Music & Dance', 'Animation']", "['Daily Vlogs']",
#        "['Video Games', 'Toys']", "['Animation', 'Video Games']",
#        "['Music & Dance', 'Humor']", "['Animation']",
#        "['Science & Technology']", "['Fitness', 'Health & Self-Help']",
#        "['Beauty', 'Fashion']", "['Humor']", "['Design/Art']",
#        "['Food & Drink']", "['Travel', 'Shows']", "['Sports']",
#        "['Fitness']", "['Food & Drink', 'Health & Self-Help']",
#        "['Health & Self-Help']", "['DIY & Life Hacks', 'Toys']",
#        "['AnimationHumorEducation']", "['Education', 'Toys']",
# ...

# %%
df1.Country.unique()
# Out:
# array(['India', 'United States', 'Unknown', 'Brazil', 'Mexico', 'Russia',
#        'Pakistan', 'Philippines', 'Indonesia', 'Thailand', 'France',
#        'Colombia', 'Iraq', 'Japan', 'Argentina', 'Ecuador', 'El Salvador',
#        'Turkey', 'Saudi Arabia', 'Bangladesh', 'United Kingdom',
#        'Algeria', 'Spain', 'Republic of Korea', 'Egypt', 'Iran',
#        'Morocco', 'Jordan', 'Singapore', 'Peru'], dtype=object)

# %%
df2 = df1[df1['Country'] == 'India']

# %%
df2
# Out:
#         Rank              Username                    Categories  Suscribers  \
# 0          1               tseries             ['Music & Dance']   253500000
# 3          4              SETIndia                   ['Unknown']   165400000
# 8          9       zeemusiccompany             ['Music & Dance']   102600000
# 11        12    GoldminesTelefilms                   ['Unknown']    92100000
# 12        13               SonySAB       ['Movies', 'Animation']    87200000
# ..       ...                   ...                           ...         ...
# 964  9682570                Panda.  ['Animation', 'Video Games']    12500000
# 982  9863043         ankitabhawsar                   ['Unknown']    12300000
# 991      995  HarshaSaiForYouHindi                   ['Unknown']    12300000
# 992      996           morharyanvi             ['Music & Dance']    12300000
# 993      997      UTKARSHCLASSES13                 ['Education']    12300000
#
# ...

# %%
df1.head()
# Out:
#    Rank       Username                Categories  Suscribers        Country  \
# 0     1        tseries         ['Music & Dance']   253500000          India
# 1     2        MrBeast  ['Video Games', 'Humor']   210100000  United States
# 2     3      CoComelon             ['Education']   168100000        Unknown
# 3     4       SETIndia               ['Unknown']   165400000          India
# 4     5  KidsDianaShow     ['Animation', 'Toys']   116500000        Unknown
#
#      Visits    Likes  Comments  Subscribers (millions)
# 0    111300     3200       120                   253.5
# 1  95400000  5400000     16600                   210.1
# 2   4100000    21600         0                   168.1
# 3     23300      239         9                   165.4
# 4   4100000     8800         0                   116.5

# %%
df1
# Out:
#      Rank          Username                Categories  Suscribers  \
# 0       1           tseries         ['Music & Dance']   253500000
# 1       2           MrBeast  ['Video Games', 'Humor']   210100000
# 2       3         CoComelon             ['Education']   168100000
# 3       4          SETIndia               ['Unknown']   165400000
# 4       5     KidsDianaShow     ['Animation', 'Toys']   116500000
# ..    ...               ...                       ...         ...
# 992   996       morharyanvi         ['Music & Dance']    12300000
# 993   997  UTKARSHCLASSES13             ['Education']    12300000
# 994   998         MBCMASRtv               ['Unknown']    12300000
# 995   999               NFL                ['Sports']    12300000
# 996  1000        MykeTowers         ['Music & Dance']    12300000
#
#            Country    Visits    Likes  Comments  Subscribers (millions)
# 0            India    111300     3200       120                   253.5
# ...

# %%
df3 = df.drop(['Visits', 'Comments'], axis='columns')[:20]

# %%
df3
# Out:
#     Rank              Username              Categories   Suscribers  \
# 0      1               tseries          Música y baile  253500000.0
# 1      2               MrBeast      Videojuegos, Humor  210100000.0
# 2      3             CoComelon               Educación  168100000.0
# 3      4              SETIndia                  Unknow  165400000.0
# 4      5         KidsDianaShow     Animación, Juguetes  116500000.0
# 5      6             PewDiePie  Películas, Videojuegos  111400000.0
# 6      7    LikeNastyaofficial                Juguetes  110400000.0
# 7      8           VladandNiki     Animación, Juguetes  105500000.0
# 8      9       zeemusiccompany          Música y baile  102600000.0
# 9     10                   WWE             Videojuegos   98100000.0
# 10    11             BLACKPINK          Música y baile   92200000.0
# 11    12    GoldminesTelefilms                  Unknow   92100000.0
# 12    13               SonySAB    Películas, Animación   87200000.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import plotly.express as px

# %%
fig = px.bar(df3, x="Username", y="Suscribers", color="Username", title ="Dr Aly Analysis of top 20 youtubers from all over the world")

# %%
fig.show()

# %%
fig.write_html('Dr_aly.html', auto_open=True)
