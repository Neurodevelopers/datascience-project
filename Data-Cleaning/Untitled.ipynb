# %%
import pandas as pd

# %%
df = pd.read_csv("fake_news_data.csv")

# %%
df.head()
# Out:
#                                          Title            Author Publish Date  \
# 0     Sister blood play next American realize.   Marie Fernandez   2022-12-29
# 1  Drive front source anyone condition animal.               NaN          NaN
# 2                                          NaN     Michael Zhang   2021-09-18
# 3              Method young together analysis.     Kathryn Parks   2021-03-06
# 4           Open live interest institution PM.  Benjamin Gregory   2021-07-05
#
#                                              Content  \
# 0  Hope remain point set character. Group well th...
# 1  Apply less would concern while look together a...
# 2  Believe adult member this.\nStreet maybe race ...
# 3  Collection face whatever relationship. Culture...
# 4  Call toward magazine different sound defense n...
#
#                      Source          Genre    Views  Shares       Location
# 0   https://rodriguez.info/        Science  73986.0    9814          Niger
# ...

# %%
df.isnull().sum()
# Out:
# Title           17
# Author          12
# Publish Date    13
# Content         28
# Source           0
# Genre            0
# Views           12
# Shares           0
# Location        11
# dtype: int64

# %%
df.head()
# Out:
#                                          Title            Author Publish Date  \
# 0     Sister blood play next American realize.   Marie Fernandez   2022-12-29
# 1  Drive front source anyone condition animal.               NaN          NaN
# 2                                          NaN     Michael Zhang   2021-09-18
# 3              Method young together analysis.     Kathryn Parks   2021-03-06
# 4           Open live interest institution PM.  Benjamin Gregory   2021-07-05
#
#                                              Content  \
# 0  Hope remain point set character. Group well th...
# 1  Apply less would concern while look together a...
# 2  Believe adult member this.\nStreet maybe race ...
# 3  Collection face whatever relationship. Culture...
# 4  Call toward magazine different sound defense n...
#
#                      Source          Genre    Views  Shares       Location
# 0   https://rodriguez.info/        Science  73986.0    9814          Niger
# ...
